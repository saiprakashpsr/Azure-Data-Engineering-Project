# %% [markdown]
# # Create catalogue

# %%
# %sql
Create catalog sales_catalog;

# %% [markdown]
# # Create schema

# %%
# %sql
CREATE SCHEMA sales_catalog.silver;

# %%
# %sql
CREATE SCHEMA sales_catalog.gold;
